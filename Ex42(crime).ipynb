# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
crime =pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv',parse_dates=['Year'])
crime.head(10)
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
# 5 1965-01-01   193526000  4739400   387390   4352000    9960          23410
# 6 1966-01-01   195576000  5223500   430180   4793300   11040          25820
# 7 1967-01-01   197457000  5903400   499930   5403500   12240          27620
# 8 1968-01-01   199399000  6720200   595010   6125200   13800          31670
# 9 1969-01-01   201385000  7410900   661870   6749000   14760          37170
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800
# 5   138690              215330   1282500        2572600         496900
# 6   157990              235330   1410100        2822000         561200
# 7   202910              257160   1632100        3111600         659800
# 8   262840              286700   1858900        3482700         783600
# 9   298850              311090   1981900        3888600         878500

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
crime.Year=pd.to_datetime(crime['Year'],format='%Y', errors='coerce')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
crime.set_index('Year',drop=True)
crime.head(10)
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
# 5 1965-01-01   193526000  4739400   387390   4352000    9960          23410
# 6 1966-01-01   195576000  5223500   430180   4793300   11040          25820
# 7 1967-01-01   197457000  5903400   499930   5403500   12240          27620
# 8 1968-01-01   199399000  6720200   595010   6125200   13800          31670
# 9 1969-01-01   201385000  7410900   661870   6749000   14760          37170
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800
# 5   138690              215330   1282500        2572600         496900
# 6   157990              235330   1410100        2822000         561200
# 7   202910              257160   1632100        3111600         659800
# 8   262840              286700   1858900        3482700         783600
# 9   298850              311090   1981900        3888600         878500

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
crime.drop('Total',axis=1,inplace=True)
crime.head()
# Out:
#         Year  Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0 1960-01-01   179323175   288460   3095700    9110          17190   107840
# 1 1961-01-01   182992000   289390   3198600    8740          17220   106670
# 2 1962-01-01   185771000   301510   3450700    8530          17550   110860
# 3 1963-01-01   188483000   316970   3792500    8640          17650   116470
# 4 1964-01-01   191141000   364220   4200400    9360          21420   130390
#
#    Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0              154320    912100        1855400         328200
# 1              156760    949600        1913000         336000
# 2              164570    994300        2089600         366800
# 3              174210   1086400        2297800         408300
# 4              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
crimes = crime.resample('10AS').sum()
#population = crime['Population'].resample('10AS').max()
#crimes['Population'] = population

crime.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\abhis\OneDrive\Desktop\RF aca\Ex42(crime).ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/abhis/OneDrive/Desktop/RF%20aca/Ex42%28crime%29.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> crimes = crime.resample('10AS').sum()
#       <a href='vscode-notebook-cell:/c%3A/Users/abhis/OneDrive/Desktop/RF%20aca/Ex42%28crime%29.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> #population = crime['Population'].resample('10AS').max()
#       <a href='vscode-notebook-cell:/c%3A/Users/abhis/OneDrive/Desktop/RF%20aca/Ex42%28crime%29.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> #crimes['Population'] = population
#       <a href='vscode-notebook-cell:/c%3A/Users/abhis/OneDrive/Desktop/RF%20aca/Ex42%28crime%29.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> crime.info()
#
# File c:\Users\abhis\anaconda3\lib\site-packages\pandas\core\frame.py:10535, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10519 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   10520 def resample(
#   10521     self,
#    (...)
#   10533     offset: TimedeltaConvertibleTypes | None = None,
#   10534 ) -> Resampler:
# > 10535     return super().resample(
#   10536         rule=rule,
#   10537         axis=axis,
#   10538         closed=closed,
#   10539         label=label,
#   10540         convention=convention,
#   10541         kind=kind,
#   10542         loffset=loffset,
#   10543         base=base,
#   10544         on=on,
#   10545         level=level,
#   10546         origin=origin,
#   10547         offset=offset,
#   10548     )
#
# File c:\Users\abhis\anaconda3\lib\site-packages\pandas\core\generic.py:8312, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8309 from pandas.core.resample import get_resampler
#    8311 axis = self._get_axis_number(axis)
# -> 8312 return get_resampler(
#    8313     self,
#    8314     freq=rule,
#    8315     label=label,
#    8316     closed=closed,
#    8317     axis=axis,
#    8318     kind=kind,
#    8319     loffset=loffset,
#    8320     convention=convention,
#    8321     base=base,
#    8322     key=on,
#    8323     level=level,
#    8324     origin=origin,
#    8325     offset=offset,
#    8326 )
#
# File c:\Users\abhis\anaconda3\lib\site-packages\pandas\core\resample.py:1423, in get_resampler(obj, kind, **kwds)
#    1419 """
#    1420 Create a TimeGrouper and return our resampler.
#    1421 """
#    1422 tg = TimeGrouper(**kwds)
# -> 1423 return tg._get_resampler(obj, kind=kind)
#
# File c:\Users\abhis\anaconda3\lib\site-packages\pandas\core\resample.py:1599, in TimeGrouper._get_resampler(self, obj, kind)
#    1596 elif isinstance(ax, TimedeltaIndex):
#    1597     return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
# -> 1599 raise TypeError(
#    1600     "Only valid with DatetimeIndex, "
#    1601     "TimedeltaIndex or PeriodIndex, "
#    1602     f"but got an instance of '{type(ax).__name__}'"
#    1603 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
# Because Above cell did not run that's why i cannot find any solution to this problem.
# Out:
# Year                  54
# Population            54
# Violent               32
# Property              31
# Murder                31
# Forcible_Rape         32
# Robbery               31
# Aggravated_assault    33
# Burglary              20
# Larceny_Theft         31
# Vehicle_Theft         31
# dtype: int64
